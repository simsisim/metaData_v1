# %%
# !pwd
from google.colab import drive
drive.mount('/content/drive')
#drive.mount('/content/drive', force_remount = True)
# Out:
# /content
# Mounted at /content/drive

# %%
pip install yfinance pandas
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.65)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)

# %%
# ==============================================================================
# CELL 3: Main script to create Google Sheets with GOOGLEFINANCE formula
# ==============================================================================

import pandas as pd
from datetime import datetime

# --- Configuration ---
# Set the path to your input CSV file in Google Drive.
input_csv_path = '/content/drive/MyDrive/_invest2024/DJIndexes_data/djindexes_googlesheets.csv'

# Set the desired output folder paths in your Google Drive.
output_folders = {
    'daily': '_invest2024/DJIndexes_data/data/daily',
    'weekly': '_invest2024/DJIndexes_data/data/weekly',
    'monthly': '_invest2024/DJIndexes_data/data/monthly'
}

# IMPORTANT: Set this to your email address so the new sheets are shared with you.
USER_EMAIL = 'imagda@gmail.com'   # <-- CHANGE THIS TO YOUR EMAIL

def get_or_create_folder(folder_path):
    """Finds a folder by path, creating it if it doesn't exist. Returns folder ID."""
    parent_id = 'root'
    folders = folder_path.split('/')
    for folder_name in folders:
        query = f"name='{folder_name}' and mimeType='application/vnd.google-apps.folder' and '{parent_id}' in parents and trashed=false"
        response = drive_service.files().list(q=query, spaces='drive', fields='files(id, name)').execute()
        results = response.get('files', [])
        if results:
            parent_id = results[0].get('id')
        else:
            print(f"Creating folder: {folder_name}")
            folder_metadata = {
                'name': folder_name,
                'mimeType': 'application/vnd.google-apps.folder',
                'parents': [parent_id]
            }
            folder = drive_service.files().create(body=folder_metadata, fields='id').execute()
            parent_id = folder.get('id')
    return parent_id



# --- Main Logic ---

# 1. Read the list of tickers from your CSV file.
try:
    print(f"\nReading tickers from: {input_csv_path}")
    df_tickers = pd.read_csv(input_csv_path, header=None)
    tickers = df_tickers[1].tolist() # Access the first column explicitly
    print(f"Successfully found {len(tickers)} tickers.")
except FileNotFoundError:
    print(f"ERROR: File not found at '{input_csv_path}'.")
    print("Please make sure you have placed the file in the correct Google Drive path.")
else:
    # 2. Define the date range
    end_date = datetime.now()
    start_date = datetime(2024, 1, 1)

    # 3. Process each interval (daily, weekly, monthly)
    intervals = ['DAILY', 'WEEKLY']  # Note: Google Finance doesn't support MONTHLY directly

    for interval in intervals:
        interval_name = interval.lower()
        print(f"\n=== Processing {interval_name.upper()} data ===")

        # Get the destination folder ID for this interval
        print(f"Ensuring output folder exists: '{output_folders[interval_name]}'")
        destination_folder_id = get_or_create_folder(output_folders[interval_name])
        print(f"All {interval_name} sheets will be saved in folder ID: {destination_folder_id}")

        # 4. Loop through each ticker, create a new Google Sheet
        print(f"\nStarting {interval_name} data sheet creation process...")
        for ticker in tickers:
            # Create the sanitized ticker name for the GOOGLEFINANCE formula (without '^')
            sanitized_ticker = ticker.replace('^', '')

            try:
                print(f"  -> Processing {interval_name} data for ticker: {ticker}...")

                # Create the Google Sheet in the desired Drive folder
                sheet_name = f"{ticker}_{interval_name}"
                spreadsheet = gc.create(sheet_name, folder_id=destination_folder_id)
                worksheet = spreadsheet.sheet1

                # Use separate formulas with proper column spacing to avoid array conflicts
                # Place each formula with enough space between columns (every 3rd column)
                formulas_data = [
                    ('A1', f'=GOOGLEFINANCE("{sanitized_ticker}", "open", DATE({start_date.year},{start_date.month},{start_date.day}), TODAY(), "{interval}")'),
                    ('D1', f'=GOOGLEFINANCE("{sanitized_ticker}", "high", DATE({start_date.year},{start_date.month},{start_date.day}), TODAY(), "{interval}")'),
                    ('G1', f'=GOOGLEFINANCE("{sanitized_ticker}", "low", DATE({start_date.year},{start_date.month},{start_date.day}), TODAY(), "{interval}")'),
                    ('J1', f'=GOOGLEFINANCE("{sanitized_ticker}", "close", DATE({start_date.year},{start_date.month},{start_date.day}), TODAY(), "{interval}")'),
                    ('M1', f'=GOOGLEFINANCE("{sanitized_ticker}", "volume", DATE({start_date.year},{start_date.month},{start_date.day}), TODAY(), "{interval}")')
                ]

                # Prepare batch updates with proper spacing
                updates = []
                for cell_range, formula in formulas_data:
                    updates.append({
                        'range': cell_range,
                        'values': [[formula]],
                        'majorDimension': 'ROWS'
                    })

                # Use batch_update to set all formulas at once
                worksheet.batch_update(updates, value_input_option='USER_ENTERED')

                # Share the sheet so you have access
                spreadsheet.share(USER_EMAIL, perm_type='user', role='writer')

                print(f"     - Success! {interval_name.capitalize()} sheet created. Link: {spreadsheet.url}")

            except Exception as e:
                print(f"     - ERROR: Failed to process {ticker} for {interval_name} data. Reason: {e}")

    print("\nScript finished. All formulas have been inserted into your specified Google Drive folders.")
# Out:
# Reading tickers from: /content/drive/MyDrive/_invest2024/DJIndexes_data/djindexes_googlesheets.csv
# Successfully found 106 tickers.
#
# === Processing DAILY data ===
# Ensuring output folder exists: '_invest2024/DJIndexes_data/data/daily'
# Creating folder: data
# Creating folder: daily
# All daily sheets will be saved in folder ID: 12QlN6UMqVgGsiAHtN3axu-MUVQfM9ImH
#
# Starting daily data sheet creation process...
#   -> Processing daily data for ticker: ticker...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/15nASyt2gY9mqqnI6qu5dq79UDNU3tlLecPegiDeWUQw
#   -> Processing daily data for ticker: ^DJUSBM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1iCzW9pfisudoLwold4V0JjUE9ayeKRgNS_yuQCPUXVY
#   -> Processing daily data for ticker: ^DJUSBT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1_481Z4OmHFnWB9QJXHiGZm1tqXx8QJAZujUTCn0AdQc
#   -> Processing daily data for ticker: ^DJUSCY...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1vnuS8sXKDhWns7bCnRed9rdkW6fpqUf8cwBx_W2Ig5M
#   -> Processing daily data for ticker: ^DJUSNC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1xHMBC1RJOlC8D2BS92JxZ2YqlUWLt50fU95VY9EmdbU
#   -> Processing daily data for ticker: ^DJUSEN...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1tHP5kIb9l4-lFiAwOifYBkd7MBoiZFzKb4JxAVkRGk8
#   -> Processing daily data for ticker: ^DJUSHC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1nIQm75j8JHDN5Lcdg6LQz2d_K0fs9_3Jkx5tXve3enA
#   -> Processing daily data for ticker: ^DJUSIN...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1P4MiIdj15lGOITNwEc0s9B-5LQRPjR7I7NfftENlQDs
#   -> Processing daily data for ticker: ^DJUSL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1xrmSDjXBdvFW649fXzTHxHDpOk_RfbBcIzXnU8-JneE
#   -> Processing daily data for ticker: ^DJUSM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1IijyTEAdfnX9EwokKz3GQrPEDEx27aAEKw6syzS8n6Y
#   -> Processing daily data for ticker: ^DJUSPR...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1wAIBpkB0tl5O4Rt5-r9oMAHFcTMrq6UPkv8LRVF4eno
#   -> Processing daily data for ticker: ^DJUSPM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1muxVvz6tdBOhkKcWP39R_5uI7EjTrdoT2ySv3DzNABo
#   -> Processing daily data for ticker: ^DJUSRE...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1WxcdpSY_MZ6EcwCH88ILzHl2471JvGHFlhYazSvMIOQ
#   -> Processing daily data for ticker: ^DJUSSC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1j7L62SCIiRf0tU44F9_KqRODxOAMSW2y49fS7OlL-xI
#   -> Processing daily data for ticker: ^DJUSS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1fxueNVqD51cIWeJfU9qGhOxX5-YzYTAJLHrZddOuj1U
#   -> Processing daily data for ticker: ^DJUSTC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Npf-ZV1myVN2PziZRur34OZ3lqcsi6qJRWofIF37z_A
#   -> Processing daily data for ticker: ^DJUSTL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1BJoC-Fxwhh1XEV_1wEnc7EfCIWKUYbhmXeknaziIA04
#   -> Processing daily data for ticker: ^DJUSUT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1joEBK5z-19JT2-GM9I1UvP_hyDSV-PJIITMtnrIxTOU
#   -> Processing daily data for ticker: ^DJUSWC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1BJpDaq7QGjmBsr40uYtdMTXiIHXDdBb7gcUCpvZVrPE
#   -> Processing daily data for ticker: ^DJUSAE...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/11uJr-gp0IKxqDboxiX3rlgtq9VutGP3x9SGZ9OUa-XA
#   -> Processing daily data for ticker: ^DJUSAF...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1hd8uNuGzupg5iJkF_DO-KnaBSTrpMUhmAvQ0u3mDO8o
#   -> Processing daily data for ticker: ^DJUSAI...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/18GQgzTrytd-v6dlkQBoMxmv47dctEM4dseJrX7KSBc4
#   -> Processing daily data for ticker: ^DJUSAL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1fqaAPSWCu8Q5GjNLhU8yTt5jocGFGTlwnzdBTLofFpg
#   -> Processing daily data for ticker: ^DJUSAM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1p9Fx_co1fT0TbkzBVrcMQ9ApDOZInUW5aGE_j_wbGSA
#   -> Processing daily data for ticker: ^DJUSAP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1YxV2tCbZ7Y-ZzpGikaLkRgRrg0-jcJ6b_tC2HMnVdbg
#   -> Processing daily data for ticker: ^DJUSAR...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/19vZSyQGeOwoZvJu1UNTOZJ0v30gfkRGOb6LpEMwPSF4
#   -> Processing daily data for ticker: ^DJUSAT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1pZ6vF74UT3F_fREtVwcLnkceUDS6dHCfhychkq1IzSE
#   -> Processing daily data for ticker: ^DJUSAU...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1oOgPCDIzn98bM9AQddFgsPE9T7Pl8jysaJoh7cb92v8
#   -> Processing daily data for ticker: ^DJUSAV...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/11-pD9pKc8OW4zg-Y2McK3znQSe78JNTi79dFUAlzgjA
#   -> Processing daily data for ticker: ^DJUSBC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/10B15P0vbS_CdcyXF2Nu791KBBlCG6V7p0MqekWNRzGs
#   -> Processing daily data for ticker: ^DJUSBD...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1bwWjjuS-0F1FsPRbSwhS4bjiztvcQu1qQectjbze180
#   -> Processing daily data for ticker: ^DJUSBK...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1-oX3Ot5acQ-zri8H0RM_8cOiN1S4Sw_aqqypwr8hkTg
#   -> Processing daily data for ticker: ^DJUSCA...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1zPCP9jtqphkIvgtkSJBh53rep67Xf0gk3woq-EH3-0Y
#   -> Processing daily data for ticker: ^DJUSCC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Rq_kA9TIdOWyaTJySF3xeeH0jwX6zZv88FtMrzNPeLE
#   -> Processing daily data for ticker: ^DJUSCF...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1FqkbrDhqMAOWR7id4FaXuVDOr0Ywf0xoiEMcfuoWXEE
#   -> Processing daily data for ticker: ^DJUSCH...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1R8FJPq6Xlgrb39kIywUP7Xah6jDcPlQH2NDkfG07a_4
#   -> Processing daily data for ticker: ^DJUSCM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1y9-KEWQf_Neg2FyndEqg502mtVL6D_9iP0eoT0_XU_4
#   -> Processing daily data for ticker: ^DJUSCN...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1VOM3NxJRA0L_ct6dBReXUOKwEBoeybe0819j8hchgZQ
#   -> Processing daily data for ticker: ^DJUSCP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1_xeDIE_WV8vO8sSFBH-rIux6EYqTvm_ChlHBT29uIzw
#   -> Processing daily data for ticker: ^DJUSCR...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1RSRAmzLksEuBZ_z_-BguLUNg_zuaE72gUPo6Ry878oI
#   -> Processing daily data for ticker: ^DJUSCS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1ui5hBUKxovNXc6u7c6otj2xcAfl81d8wj8dCSbYIdZ0
#   -> Processing daily data for ticker: ^DJUSCT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1iQtgD6_CCa6WaZq79DZufkwU0ihQ7GJEqLp98c5beNk
#   -> Processing daily data for ticker: ^DJUSCX...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1MBJnjAcMWnfGGFvbuZLTuYS_ZGG11UDr9oKS7Zn0MmI
#   -> Processing daily data for ticker: ^DJUSDB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1mCAVsaUbE6-fGba1-MLfJpMj0UCLAW_GlavW4BFjTRg
#   -> Processing daily data for ticker: ^DJUSEU...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/14tfBQvuGwLDiA1bWLv6Bw2_xLXtxXYxr7TNmCP0_d3U
#   -> Processing daily data for ticker: ^DJUSFB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1dXyegIISaPwxtJo4CVTGrxEhh0OXbWlM9LiDGf-WJxo
#   -> Processing daily data for ticker: ^DJUSFC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1luctuyDZxTzdBmriKvRW7oYzAFp3OxmEVxGQxZJoF2E
#   -> Processing daily data for ticker: ^DJUSFD...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Ed239ZbFLmMzjs7Wjv96Pwa7fDxV2wM3Q_5i2iTt6RA
#   -> Processing daily data for ticker: ^DJUSFE...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1nrjcBPhOa-UbxDP3uZ2sDXq-iRzzH8_7mBic36RqHAY
#   -> Processing daily data for ticker: ^DJUSFH...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1M6z0JifZsDCV4RkUV9NrIv72i830knQ52d-LlaQM1bY
#   -> Processing daily data for ticker: ^DJUSFP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1jwTe6gjlFIBPcbchQZXz9ogWxoHOFdXT6Eahn27mrEY
#   -> Processing daily data for ticker: ^DJUSFT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1WN2MpJgDBx7diVOiq7lFHAgmXOP57-e7Vt3bBivZfIY
#   -> Processing daily data for ticker: ^DJUSGL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1ttg-R-KeaQ_Ktf5YvS13Nb758ROlNiBAoxMFQn_7kT4
#   -> Processing daily data for ticker: ^DJUSGM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1FayrZOyBGyBTQ8JKz8SVgLel-EBeMj7wCLPD075NMqo
#   -> Processing daily data for ticker: ^DJUSGS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1gVq8dQa5_0aJUdnPE796XvEAFnNPa75Pu6zdaB1_oI8
#   -> Processing daily data for ticker: ^DJUSGU...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Eo2VuSqytEnkFrVi72bPQE7GRFI0-VFwH_sDvR46ZLQ
#   -> Processing daily data for ticker: ^DJUSHB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1-Cn1cBX5YV5D38Wa4YwnwWEo3vhFwvvloCMFVXn0MHQ
#   -> Processing daily data for ticker: ^DJUSHD...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1su5ZNO0m0k2LwQMxkRkE7IrYWmRjlTLYFEVpWyz2y5k
#   -> Processing daily data for ticker: ^DJUSHN...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1dUL15p1Ga1I8iRL24ZW64Z5WdlHMJT2zWXBFzTNfoV8
#   -> Processing daily data for ticker: ^DJUSHP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1LMrTbUM5OmkXU9uUdVJwSrkmvl0a_Mfj2LnMQTNBoT8
#   -> Processing daily data for ticker: ^DJUSHR...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1vbgEMyGYP9FvFxpnKKfjan87PMF0nQxHMCfXB5ofQOM
#   -> Processing daily data for ticker: ^DJUSHV...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1bvkk7cZroWW7LAi5nqYqxhUb0B7iYh9gRvCfdfGMYo8
#   -> Processing daily data for ticker: ^DJUSID...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/14Js8RviFLsIjwx60hzTx-TSXysvuepSqn9WHN_CdF38
#   -> Processing daily data for ticker: ^DJUSIF...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1tOyFed4MY6LycVktAUsqPZCt02OQrbGA0C5zj1bqHO0
#   -> Processing daily data for ticker: ^DJUSIL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1NskRwIeT2VIhb6NkxEzEncWR892nL9LtJ7weMp-VdUQ
#   -> Processing daily data for ticker: ^DJUSIP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1WdpB66XGXXxDB_9RM8g6c_zJ3Q7k0ZX8FSBBtjIITLQ
#   -> Processing daily data for ticker: ^DJUSIR...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1xtO9NWuGNZLp4EP1eKfo0m0zFU3BwfTljeBmJAAsZUE
#   -> Processing daily data for ticker: ^DJUSIS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1m_1RUyIwZf8748ZtkeXuqqdYvXeWNIYBlBqfRWUis_w
#   -> Processing daily data for ticker: ^DJUSIT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Gp_7IZA__yLzYJ_TN80-E_uFiHjEExNaYRao3TR9eP8
#   -> Processing daily data for ticker: ^DJUSIV...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1TSSLA-73qr5cWbn_j560q2LES4VHDD_4j_NQSs1iy2Q
#   -> Processing daily data for ticker: ^DJUSLG...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1qPW8VllhdX8nTuXq31hopJVJ5Clme40GXnpfP60CtFw
#   -> Processing daily data for ticker: ^DJUSLW...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1mXTJOK48xE2YSYJBStB-fnuDdWwU_UYSMsU5wth_7ck
#   -> Processing daily data for ticker: ^DJUSMT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1afuW3KFXi_sDBmEgbRxJ1RskLm0fLR7S1Wvhac-15JM
#   -> Processing daily data for ticker: ^DJUSNF...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1jX7FqdZ0rVUcdJKvGLghPkUZKeO7V_mFszdkEXXoxEo
#   -> Processing daily data for ticker: ^DJUSOL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1uOdE79FsySUcq40Yy_uF_MsHNOqlvOvxQKgRfaCB-Po
#   -> Processing daily data for ticker: ^DJUSOS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1gM10O4wTts9wBkJqNP3iVDKBeejxXDg4-aizodrB8MQ
#   -> Processing daily data for ticker: ^DJUSPB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1rWrFyrMuVjmDLctabTVPHbN0DPbXBlICkbLSW4DY_x0
#   -> Processing daily data for ticker: ^DJUSPC...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Cf2S2VcHyLiLReImPrZAzhBOCqCcYQjD63O48accGyc
#   -> Processing daily data for ticker: ^DJUSPL...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1AM82RgUsKgp9b1NxIN2WYKalkvVvWXol_sKS2Io5JGk
#   -> Processing daily data for ticker: ^DJUSRA...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1OCkpmSToH__JdpLr5wHnslHfYbaLqmc9a69egSOgnVw
#   -> Processing daily data for ticker: ^DJUSRB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1cWgFUBzMtQk40gn56TtZV2sHEfGZAh-iujiNIlKAjXI
#   -> Processing daily data for ticker: ^DJUSRD...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1QNPz419Q6NzHZDqgSfUBrRHPdtRgvsxrwm8v_NyoLD8
#   -> Processing daily data for ticker: ^DJUSRP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1-d2poH_414eExiBPLLwwE_VTnvz-PgRqGonY1YfjZNA
#   -> Processing daily data for ticker: ^DJUSRR...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1nCp-0S-aXdKaWxcnb28Nhw0TrcQFZ_bqWeLqoeuCmuk
#   -> Processing daily data for ticker: ^DJUSRS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1fpTzG07lu3bwNOrk8w6gA1-RyYD-LkjhO6pWGP1JErA
#   -> Processing daily data for ticker: ^DJUSRT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1_o_jDNrrXjuootC_tV-m9am3togwNV0ZZmRFMD8rj0o
#   -> Processing daily data for ticker: ^DJUSRU...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/160CrZ3M7a5GQ-yrZv6ph5xzrWVlDlSVSLmZ5MLTty4M
#   -> Processing daily data for ticker: ^DJUSSB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1896upKQlyuqe0QvlII4dbVs1uPOOraUf7VtUDVClLSo
#   -> Processing daily data for ticker: ^DJUSSD...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1a5Tu7hZor3Qa7N0_u4Fnyk0GsethFC9lUx802ROJUXY
#   -> Processing daily data for ticker: ^DJUSST...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/13eM0CWRiP30MAHZdKV4a3jEO5EIJGZfqdVziWTyqO1Q
#   -> Processing daily data for ticker: ^DJUSSW...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1z97nLS5wg_7SF3929lKAxdpibnA3sxFezTRiaXhUkCA
#   -> Processing daily data for ticker: ^DJUSTB...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/10rpuJDhsY2kVmENinttpkI8IM-H2L8k-mImsPdufnn8
#   -> Processing daily data for ticker: ^DJUSTK...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1bHhWpkB7JIqfeKdomlT21VOMlo5OUMh-GOnmo4C-QrA
#   -> Processing daily data for ticker: ^DJUSTP...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1nlDqrsLjLtAaxtrb8qIgRVUZ3Mxv689bK-NC9AU5yxE
#   -> Processing daily data for ticker: ^DJUSTY...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1icgp0GuHHQoWELo_CsvlGATGXVfu1INBv_HaXG8YUWo
#   -> Processing daily data for ticker: ^DJUSVM...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1HPI_omlRGJnXajLr0dkQrnZpWcvzclOkDcYEbUBK4WU
#   -> Processing daily data for ticker: ^DJUSVS...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1HfgqDVQ39Y7N2d6SgkV0GU3mhnyJVH5LcetWplW5nFs
#   -> Processing daily data for ticker: ^DJUSWU...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1SZg8gL3nn96JBP9zyZRMsMX9FdHr1XBkoGjkRYx4-6g
#   -> Processing daily data for ticker: CRSPLC1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1hgKyKQcs2FbukGFoUyO4JxqnaQGTx5wkUZa5ZHUKfWo
#   -> Processing daily data for ticker: CRSPME1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1L4uMML4Lxv2YXOndyV0jNP2Ue3SEN-cq5VyyvJ0iZ4M
#   -> Processing daily data for ticker: CRSPXM1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1Pl_blxTLNZr6Fc0LLxq4QzEJaJNPcc6PYAdFtoWOgPo
#   -> Processing daily data for ticker: CRSPMI1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/10OsfJJDXsCB_AJt0xf7s9vFRfKPvOHa2ccDMoymBksc
#   -> Processing daily data for ticker: CRSPSMT...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/15Ul7TO4WNkzP1f2-xePral3OapVzd-8UJgwCzZrpt1g
#   -> Processing daily data for ticker: CRSPSC1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/189XMqnySNYWYjf_1a4_alh2Ke4FDbGLx6m5IN92AcH4
#   -> Processing daily data for ticker: CRSPMS1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1w5RipAtusqeIOZZl5_TtbSH_GA-aTon-nBmevl-glP8
#   -> Processing daily data for ticker: CRSPMC1...
#      - Success! Daily sheet created. Link: https://docs.google.com/spreadsheets/d/1gwios02Vdc0W1bSFibAmXehmssatk56RihLsg2fD_Ac
#
# === Processing WEEKLY data ===
# Ensuring output folder exists: '_invest2024/DJIndexes_data/data/weekly'
# Creating folder: weekly
# All weekly sheets will be saved in folder ID: 1lYXtWeYKRQFq8XpaliLrgOrtlVLbi5UQ
#
# Starting weekly data sheet creation process...
#   -> Processing weekly data for ticker: ticker...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1fMB2c6rv8SGHgiGNQ5L-wTG2llQoov6EJEaCtW4xzwQ
#   -> Processing weekly data for ticker: ^DJUSBM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1_H_O_cv8zMm59sAHskfP29Di8BtigHiDr3ga9vQk9w8
#   -> Processing weekly data for ticker: ^DJUSBT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/14w91tEYjCX0zyxy7Fqmskuat4X-Ze5p4dI5rc5zhWWg
#   -> Processing weekly data for ticker: ^DJUSCY...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1zO4tV-_jwPM-ImggiJeYblaLRVwi55hw1LaNL6cKniE
#   -> Processing weekly data for ticker: ^DJUSNC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1L0WtbWDdFM_XC4CbGA1PYWbCq0Fc-GSQZTveBEsP8To
#   -> Processing weekly data for ticker: ^DJUSEN...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/14vlb8Ghyb7j8J4QGaa6J-bKxVcjCEYPoAbzb0pvX0k8
#   -> Processing weekly data for ticker: ^DJUSHC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1tzeJ7auVF85vIjdIJdDDsDx9hvXYbrm4y2SqWLYUQ_w
#   -> Processing weekly data for ticker: ^DJUSIN...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1WV5slSaCGIanm74sKUkRdMlKClBA7OkmyzNw5a5jQu0
#   -> Processing weekly data for ticker: ^DJUSL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1H_75u-RQlwAXaUz9JPEQ19JpqU8NnaQuOMmQsSKXylo
#   -> Processing weekly data for ticker: ^DJUSM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1lAyv_Jw0-2qt1cOH4ml4LyGa7hazQKlvkhpHPIJhQuY
#   -> Processing weekly data for ticker: ^DJUSPR...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1EBP3wR9zqGM2FWMZud_MrqWYv1jDc4GI_IQiz6rx4-A
#   -> Processing weekly data for ticker: ^DJUSPM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/17q1i6iiPvRfxgnKSwzopD-y4sVqDL7zuNu8ePXHJk9E
#   -> Processing weekly data for ticker: ^DJUSRE...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1CWKKsVl2T0JQm92hYozSy9rXED3CTNodOLR8Bc0v5ng
#   -> Processing weekly data for ticker: ^DJUSSC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1qn1sHoGauXO3ok9EXDGmgfawAQUs-cUKcAApWuUn7Bc
#   -> Processing weekly data for ticker: ^DJUSS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1_1S4snH17Tbq_Tz5jsYgU0xPNka2V0kA1jSaqFNZUWs
#   -> Processing weekly data for ticker: ^DJUSTC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1yHZzDekXXL3ok2JNlS5cPcU_s4cSu44c7rQF-9M2M8E
#   -> Processing weekly data for ticker: ^DJUSTL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1viYbq3SbejL5JMX4c4FDUiAmf7uAqzr4syQtANqcdg4
#   -> Processing weekly data for ticker: ^DJUSUT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/15_kr_oMq0HaTYmjPyOK6sxDLgFr2_MREvdUFhlwy6as
#   -> Processing weekly data for ticker: ^DJUSWC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1Iiad_3eDhBLPlSb5s-TxVahs_lQfujxwXCxtH16ic7I
#   -> Processing weekly data for ticker: ^DJUSAE...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1gIu3Ef4aDwxmIIxevUkG3R9okmEww72e8XempUatM2w
#   -> Processing weekly data for ticker: ^DJUSAF...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1zJ9dR1-cWtfbamhtsroS7_kHc_UTffvIAE5WJnW-2R4
#   -> Processing weekly data for ticker: ^DJUSAI...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1ZWPu72GvFN0UzmjbnMxTo-uYZELbCP0O3xtY80PkA3s
#   -> Processing weekly data for ticker: ^DJUSAL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1SQ5DAh6K-RDabmnp0WyF0uw2p4jX3ZXQPCytLxM5Kx0
#   -> Processing weekly data for ticker: ^DJUSAM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1SaJSaUnpS7CJIQQH3N7C61WkLvn1Os27r0h0q6pF0JM
#   -> Processing weekly data for ticker: ^DJUSAP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1S9mWk1VMMjIFGgAPnYE5K7ILxso37mgUCL9Z-vP-ssk
#   -> Processing weekly data for ticker: ^DJUSAR...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1EL9qmHhufixLSAlj93s5ZJomb4_-Sj_mcmeH-r2PkpE
#   -> Processing weekly data for ticker: ^DJUSAT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1pOQxnI8cUbfJQJ-KmTxJJeklKgxZN7tRuLeai41XU7Y
#   -> Processing weekly data for ticker: ^DJUSAU...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1uR40JNYnzKJluOyk814t577gDNQBfuFFhcVAqV4K8bc
#   -> Processing weekly data for ticker: ^DJUSAV...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1-MMC-VYJaUoqXUpHUx3kvWgSiyFirtcYLCsZl6sldKg
#   -> Processing weekly data for ticker: ^DJUSBC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1ZGmTsg97vIyVx8ggXqEHJt0yGVp2vL7S5wUVY-O2AhY
#   -> Processing weekly data for ticker: ^DJUSBD...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1KAq_yGDDyFnz54s3IdgwIp0lkBD0cLyz_qzBDqcgipM
#   -> Processing weekly data for ticker: ^DJUSBK...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1GbxaSbdzdrCVvX3G6BmozPmRDeWP-lX3gOSFiYtCQzk
#   -> Processing weekly data for ticker: ^DJUSCA...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1ZIH4I1tWjtuHI3DxcrGVeEjZf-RipCyBl2Sju55e1dk
#   -> Processing weekly data for ticker: ^DJUSCC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1vwtrLb3yD3DTN9OR5cb2isVV_qW0BMjllclmuDgwvAI
#   -> Processing weekly data for ticker: ^DJUSCF...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1ksQFkP5umuVhMZcReB__Ju6EZltzMuoOjGJgFCsvIi8
#   -> Processing weekly data for ticker: ^DJUSCH...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1Ykqd8F-IZKtflB8OtrB_peuSsJ6tlqvYUdzppZd7x0I
#   -> Processing weekly data for ticker: ^DJUSCM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1oRpX5wfD-a5L8i0z9pChenMLVR8NKYUQ6jBsTPXo1sY
#   -> Processing weekly data for ticker: ^DJUSCN...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1VAeyRrsl7_sx3Bz5zXDDOfATJqgfYTjrLHziN0VHg5U
#   -> Processing weekly data for ticker: ^DJUSCP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1DrtMRhRixHkh2-Up_crygOwyHQUrK-60KuchINjXe3M
#   -> Processing weekly data for ticker: ^DJUSCR...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1AkdT2RZtl4XIHj8S19WDZwMUA-Eep2vvow7jq6Pd9IU
#   -> Processing weekly data for ticker: ^DJUSCS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/19tTUHyZT-vMBI0QSE_sfxwDhodZfDavJnvCrPCxl-6c
#   -> Processing weekly data for ticker: ^DJUSCT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1fnuudp5u-99Y6bOKecIGE8xg9OdDHCd0vkjtqLUcvVg
#   -> Processing weekly data for ticker: ^DJUSCX...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1Tm6pTIf-Or9PcggxU3-chwpIlweaPM2jvfht9w5VMjg
#   -> Processing weekly data for ticker: ^DJUSDB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/19aWF2X2Q7isHCfwI2rQcSJSzm_FUgvej1mMjR5RCQ5s
#   -> Processing weekly data for ticker: ^DJUSEU...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1liH3t8rGz9K2PBWB6KnUvehlUYtTwqsGaNuZ4PIzgT8
#   -> Processing weekly data for ticker: ^DJUSFB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1wuvwxhz29qBzCiTUmY-VwUqqkEj0S4hDaZ8Weu1VeMw
#   -> Processing weekly data for ticker: ^DJUSFC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1qPZoQ-ycdxenRYdghFInya8kv6X10IuiOAK3zX4mn9w
#   -> Processing weekly data for ticker: ^DJUSFD...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1UMkVXn2A5vHJNumH96g31239ExB_IfGchvfp_wqKrNU
#   -> Processing weekly data for ticker: ^DJUSFE...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/16qa_rZqgw15uSd6J2vEHN83yPjAmAM9tHg-ayx2QKI4
#   -> Processing weekly data for ticker: ^DJUSFH...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1jROcXdVkqNI8SDOfSpSE4C6Jy-8I7Wqt91CFK442c-Y
#   -> Processing weekly data for ticker: ^DJUSFP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1O__hlPBweHFPtg2ezaJqIronAcK9gABDzpq_A58l6Gk
#   -> Processing weekly data for ticker: ^DJUSFT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1PvzIcd3pHKjXOIunlrjJkBedvt7Jfdl75SsT-UJE_OM
#   -> Processing weekly data for ticker: ^DJUSGL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1vDeBC_bcnXh9Y9Xxg-ipsWvmtH5Jita1GYiWcJJ8uLw
#   -> Processing weekly data for ticker: ^DJUSGM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1UeZf_wM42N6sEF-KLpqdOoAywWKXifKjx1ziA7PYohw
#   -> Processing weekly data for ticker: ^DJUSGS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/16cTFdEBHVRImYWELjZv2-xMLoQMJSrq5m1VK4CLEVSQ
#   -> Processing weekly data for ticker: ^DJUSGU...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1tKAmce7dDFvvy-VqeRwfC-omBkqz7HfcDZLJGEfPK7A
#   -> Processing weekly data for ticker: ^DJUSHB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1_hM-WeQgt3vFs07FTfaH9Cf1NSKSlLRS2vyRVwpsxJk
#   -> Processing weekly data for ticker: ^DJUSHD...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1fxrieJtJkOVICyDxebJ7vrm_mVGXK-7RNAJtje192gM
#   -> Processing weekly data for ticker: ^DJUSHN...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1_LlDAks2Os9WNC8gqd8ZFjHk3O6W_qg-xfKq9rkHfN4
#   -> Processing weekly data for ticker: ^DJUSHP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1tGlRjhmhtxTiODXJQyaOY_jb2ErUVg8DslN4hyUdZEw
#   -> Processing weekly data for ticker: ^DJUSHR...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1tSGqZkl5c8xk4e7Z-mRrNA27YQw00GvOvW7kSI9NIQM
#   -> Processing weekly data for ticker: ^DJUSHV...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1Mjhq6Rd6PCjkn9gaGQ9JPL_rLxlKACXUyJyusm6fOBY
#   -> Processing weekly data for ticker: ^DJUSID...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1oEGUQr0hAEVwXXVSFDv9ih8Oso26JN95VR3t5aId0qo
#   -> Processing weekly data for ticker: ^DJUSIF...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1sGms78ScPCBnQt6qU2I9PomWvfzq-HIQpgvq7wWq61U
#   -> Processing weekly data for ticker: ^DJUSIL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1M9UiUklNFKPrxS_JTEGxgg_xv3bCQ33MAxb1X31uM7A
#   -> Processing weekly data for ticker: ^DJUSIP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/17b84gHfWyotXIaTwhQU85wUi25DaDciMUOMKI72-CLA
#   -> Processing weekly data for ticker: ^DJUSIR...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1Lcvd_hfdsy_cUQKZC6L4zb9LCWDQQnHuXF8SPhTQnHs
#   -> Processing weekly data for ticker: ^DJUSIS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1VHwEDcG6HW42XUIWPAvK_bX2a4EfkQE7m_N3JPUItPA
#   -> Processing weekly data for ticker: ^DJUSIT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1H55_JApOHpUXWf-v9r84IWc4h5jKWN8QDlzG8oVWd7I
#   -> Processing weekly data for ticker: ^DJUSIV...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/155AiQeoZ89jkBGUrEBNZNvDaNbQ7WubieOVsChHMGl0
#   -> Processing weekly data for ticker: ^DJUSLG...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1Y_lukI1CYFW90ZJvPQ8QIxgr_Bj9oIY8OHmwZXYmG2c
#   -> Processing weekly data for ticker: ^DJUSLW...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/12T1qHj6PUUHj-7bdX6ZI9eWKiQM0kpN25ZYBM6_CVNM
#   -> Processing weekly data for ticker: ^DJUSMT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1HSlliSRr_2PvIirPzrLKVjkNbHS6aaTVBPOOLqlslaA
#   -> Processing weekly data for ticker: ^DJUSNF...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1YdsUlUiKJWiLg6JBc2-z8mMRTN8TptdmwPzX7mkbogU
#   -> Processing weekly data for ticker: ^DJUSOL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/13rfCyTQRdwuxidIXIiNA6OfRzRTA5O_GoRd1b_Km4hw
#   -> Processing weekly data for ticker: ^DJUSOS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1wW-yC76XRlbdCJENtj71SHr6uotsxH514XVDPz3DQLA
#   -> Processing weekly data for ticker: ^DJUSPB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1_UE4U8AvjS0VFJe5aFI-Sn89BZEN5BCPHlpYbJn6N9E
#   -> Processing weekly data for ticker: ^DJUSPC...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1zU0yj6k8ZaQc1iy5EUbA4tt38C1uZcmsSqi8qTeXEaE
#   -> Processing weekly data for ticker: ^DJUSPL...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1If1cRmTBl6S7K3Zh0Vo9YJEwQny21ThJ4pqFstjwur0
#   -> Processing weekly data for ticker: ^DJUSRA...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1qByT3KqvCvpAuE_lrbR8bb3ffcSAKwDiL1yF3ZCTnVk
#   -> Processing weekly data for ticker: ^DJUSRB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1TMMODo6OAk_zn41FyUzlkLejAX9_xsfbL6utPkuD1Ek
#   -> Processing weekly data for ticker: ^DJUSRD...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1cDyOLs7OtB2xCkjBPPzvZeGlszuV-SR1sfUswsCv7ko
#   -> Processing weekly data for ticker: ^DJUSRP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/15ekDHlbRU8QDVJTZrreQF91ua_JVw3dFLSOpK048MNQ
#   -> Processing weekly data for ticker: ^DJUSRR...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1dQydUYGvylDH2sTl1fJqgQ9I9MmaOSELLDxA9hpDaK4
#   -> Processing weekly data for ticker: ^DJUSRS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1wmj9lPaFWUljU72rlJIu31pMQzjwiwx3KWL7riFE4FA
#   -> Processing weekly data for ticker: ^DJUSRT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1MDAC4lEKZsqLTmE1MhsWxVr0xfcQ8C2ESLamBGCA5j4
#   -> Processing weekly data for ticker: ^DJUSRU...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/16KVr13SSQqTUDMvWxiG_dAPeb8yd_v6PekL3JgXLufU
#   -> Processing weekly data for ticker: ^DJUSSB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1l6yH8SWntSZMyS0CFbg13XEIIbCJJ17dYaFL1Un0hfE
#   -> Processing weekly data for ticker: ^DJUSSD...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1UrPXOTVbSaZGV9gJXh2SmdYWm-NN4FoFtkjyXJwU3w8
#   -> Processing weekly data for ticker: ^DJUSST...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1oS-fe_G2loPDIykD-RG6mFz4PJMesjFUo2S4KTlaMy8
#   -> Processing weekly data for ticker: ^DJUSSW...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1g8ZBHSB7rWwKEoVuxurObOrGy7m4P4CG6fY5Ko269zo
#   -> Processing weekly data for ticker: ^DJUSTB...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1IxwEkyxMY2n9L_xv25K5OeV8aHqb8Hpdhbw7kodqNao
#   -> Processing weekly data for ticker: ^DJUSTK...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1knfrFDQpM3NhuQGSrHr-jG6xjC_q1eqxXgXCFIZuarY
#   -> Processing weekly data for ticker: ^DJUSTP...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1mVD4lkPIqnwV7uGpweSL3iBQI4XhJ6VoK3F-H2dsedM
#   -> Processing weekly data for ticker: ^DJUSTY...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1xpo-4oml-i-gBdnjLHoZWQFsampH_uZpsGYkS4XLvLM
#   -> Processing weekly data for ticker: ^DJUSVM...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1BUt50E87mFp7hwhGNlQn04mxW1xkapfjdjAJ2-MlqoM
#   -> Processing weekly data for ticker: ^DJUSVS...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1y0-tffe5DdNaqs_ue2-iPXudNKZXuArbcZqBAaQG2Ek
#   -> Processing weekly data for ticker: ^DJUSWU...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1nlnHaJLCUfXt47jDZ9EDUGmcAL8LQLVgmld05eji0No
#   -> Processing weekly data for ticker: CRSPLC1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1fjGSpPzPK4XxJk5g-WbyRRXkVSJcVwk29tU9XitKZ2A
#   -> Processing weekly data for ticker: CRSPME1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1pVK8-31odWXCHjiXbpFarOX0025yNQfrVxt4r6ryeY0
#   -> Processing weekly data for ticker: CRSPXM1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/15ZfSrMkbMBZKSlkNZn2G6Gciv25wHSPy3d6KIZo3kT4
#   -> Processing weekly data for ticker: CRSPMI1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/16TVMx3OD_fVG4_rMV0vNLsR6O3zxhJnCuznm2DMouZ8
#   -> Processing weekly data for ticker: CRSPSMT...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1DYKgybOQMjLBw2vjceZ5LInFwRCXyPIlPw_vU9M0hRY
#   -> Processing weekly data for ticker: CRSPSC1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1We-FTrF9-Mt4yi50FDEt1bJt4O5_v0mV0uMIG-LPpVE
#   -> Processing weekly data for ticker: CRSPMS1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1apkK-YkZhOCCNV3dlp2C3Vm_feMEm3nKPnQeBQ8MJCw
#   -> Processing weekly data for ticker: CRSPMC1...
#      - Success! Weekly sheet created. Link: https://docs.google.com/spreadsheets/d/1o3iycqQ35ULWgDyPHApL0DpJAhK1G5-NBw2NmTkpn6M
#
# Script finished. All formulas have been inserted into your specified Google Drive folders.
